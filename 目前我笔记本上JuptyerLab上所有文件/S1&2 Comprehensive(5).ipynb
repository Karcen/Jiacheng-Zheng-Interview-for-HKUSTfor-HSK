# %%
import matplotlib.pyplot as plt
import pandas as pd



# Read Excel file
df = pd.read_excel(r'C:\Users\Jiacheng Zheng\Desktop\放在桌面的文件\draw figures\Python Final\Figure3\Figure 3 stacked bar chart\WTO_OECD.xlsx', sheet_name='Con_S1&2')

# Define data columns
labels = df['Labels']

# EU
CBAM_Avg_EU = df['EU_CBAM_Avg.']
BAT_Avg_EU = df['EU_BAT_Avg.']
Imports_Avg_EU = df['EU_Imports_Avg.']
LDCs_Avg_EU = df['EU_LDCs_Avg.']
Priced_Avg_EU = df['EU_Priced_Avg.']
Elec_Avg_EU = df['EU_Elec_Avg.']
Priced_Elec_Exc_Avg_EU = df['EU_Priced_Elec_Exc_Avg.']

CBAM_Tercile_EU = df['EU_CBAM_Tercile']
BAT_Tercile_EU = df['EU_BAT_Tercile']
Imports_Tercile_EU = df['EU_Imports_Tercile']
LDCs_Tercile_EU = df['EU_LDCs_Tercile']
Priced_Tercile_EU = df['EU_Priced_Tercile']
Elec_Tercile_EU = df['EU_Elec_Tercile']
Priced_Elec_Exc_Tercile_EU = df['EU_Priced_Elec_Exc_Tercile']

# US
CBAM_Avg_US = df['US_CBAM_Avg.']
BAT_Avg_US = df['US_BAT_Avg.']
Imports_Avg_US = df['US_Imports_Avg.']
LDCs_Avg_US = df['US_LDCs_Avg.']
Priced_Avg_US = df['US_Priced_Avg.']
Elec_Avg_US = df['US_Elec_Avg.']
Priced_Elec_Exc_Avg_US = df['US_Priced_Elec_Exc_Avg.']

CBAM_Tercile_US = df['US_CBAM_Tercile']
BAT_Tercile_US = df['US_BAT_Tercile']
Imports_Tercile_US = df['US_Imports_Tercile']
LDCs_Tercile_US = df['US_LDCs_Tercile']
Priced_Tercile_US = df['US_Priced_Tercile']
Elec_Tercile_US = df['US_Elec_Tercile']
Priced_Elec_Exc_Tercile_US = df['US_Priced_Elec_Exc_Tercile']

# OECD
CBAM_Avg_OECD = df['OECD_CBAM_Avg.']
BAT_Avg_OECD = df['OECD_BAT_Avg.']
Imports_Avg_OECD = df['OECD_Imports_Avg.']
LDCs_Avg_OECD = df['OECD_LDCs_Avg.']
Priced_Avg_OECD = df['OECD_Priced_Avg.']
Elec_Avg_OECD = df['OECD_Elec_Avg.']
Priced_Elec_Exc_Avg_OECD = df['OECD_Priced_Elec_Exc_Avg.']

CBAM_Tercile_OECD = df['OECD_CBAM_Tercile']
BAT_Tercile_OECD = df['OECD_BAT_Tercile']
Imports_Tercile_OECD = df['OECD_Imports_Tercile']
LDCs_Tercile_OECD = df['OECD_LDCs_Tercile']
Priced_Tercile_OECD = df['OECD_Priced_Tercile']
Elec_Tercile_OECD = df['OECD_Elec_Tercile']
Priced_Elec_Exc_Tercile_OECD = df['OECD_Priced_Elec_Exc_Tercile']

dataflag = 0

bar_width = 1  # Change from bar_width to bar_width for horizontal bars



CBAM_Covered = '#c8b5d7'
LDCs =   '#ae8dc3'   
Imports = '#FFFF00'   
BAT_A = '#f4eb32'
BAT_T = '#e76254'
Elec = '#BC8F8F'

fig, ax = plt.subplots()  # Adjusted the figsize for a vertical layout

plt.rcParams['font.family'] = 'Garamond'
plt.rcParams['font.style'] = 'normal'



# EU bars
# EU Avg.
bars_1 = ax.bar(labels[0],
                 CBAM_Avg_EU,
                 color=CBAM_Covered,
                 width=bar_width,  # Changed from width to width
                 edgecolor='white',
                 linestyle='--',)
bars_2 = ax.bar(labels[1],
                 Priced_Avg_EU,
                 color=CBAM_Covered,
                 width=bar_width,  # Changed from width to width
                 edgecolor='white',
                 linestyle='--')
bars_3 = ax.bar(labels[1],
                 LDCs_Avg_EU,
                 color=LDCs,
                 width=bar_width,  # Changed from width to width
                 bottom=Priced_Avg_EU)
bars_4 = ax.bar(labels[1],
                 Imports_Avg_EU,
                 color=Imports,
                 bottom=Priced_Avg_EU + LDCs_Avg_EU,
                 width=bar_width)
bars_5 = ax.bar(labels[1],
                 BAT_Avg_EU,
                 color=BAT_A,
                 bottom=Priced_Avg_EU + LDCs_Avg_EU + Imports_Avg_EU,
                 width=bar_width)
bars_6 = ax.bar(labels[2],
                 Priced_Elec_Exc_Avg_EU,
                 color=CBAM_Covered,
                 width=bar_width,  # Changed from width to width
                 edgecolor='white',
                 linestyle='--')
bars_7 = ax.bar(labels[2],
                 Elec_Avg_EU,
                 color=Elec,
                 bottom=Priced_Elec_Exc_Avg_EU,
                 width=bar_width)

# flag
bars_flag = ax.bar(labels[3],
                    dataflag,
                    color='white',
                    width=bar_width)

# EU Tercile
bars_8 = ax.bar(labels[4],
                 CBAM_Tercile_EU,
                 color=CBAM_Covered,
                 edgecolor='white',
                 linestyle='--',
                 width=bar_width,)

bars_9 = ax.bar(labels[5],
                 Priced_Tercile_EU,
                 color=CBAM_Covered,
                 width=bar_width,  # Changed from width to width
                 edgecolor='white',
                 linestyle='--')

bars_10 = ax.bar(labels[5],
                  LDCs_Tercile_EU,
                  color=LDCs,
                  width=bar_width,  # Changed from width to width
                  bottom=Priced_Tercile_EU)

bars_11 = ax.bar(labels[5],
                  Imports_Tercile_EU,
                  color=Imports,
                  bottom=Priced_Tercile_EU + LDCs_Tercile_EU,
                  width=bar_width)

bars_12 = ax.bar(labels[5],
                  BAT_Tercile_EU,
                  color=BAT_T,
                  bottom=Priced_Tercile_EU + LDCs_Tercile_EU + Imports_Tercile_EU,
                  width=bar_width)

bars_13 = ax.bar(labels[6],
                  Priced_Elec_Exc_Tercile_EU,
                  color=CBAM_Covered,
                  edgecolor='white',
                  linestyle='--',
                  width=bar_width)

bars_14 = ax.bar(labels[6],
                  Elec_Tercile_EU,
                  color=Elec,
                  bottom=Priced_Elec_Exc_Tercile_EU,
                  width=bar_width)

# flag
bars_flag = ax.bar(labels[7],
                    dataflag,
                    color='white',
                    width=bar_width)

# US
# US Avg.
bars_15 = ax.bar(labels[8],
                  CBAM_Avg_US,
                  color=CBAM_Covered,
                  edgecolor='white',
                  linestyle='--',
                  width=bar_width,)

bars_16 = ax.bar(labels[9],
                  Priced_Avg_US,
                  color=CBAM_Covered,
                  width=bar_width,  # Changed from width to width
                  edgecolor='white',
                  linestyle='--')

bars_17 = ax.bar(labels[9],
                  LDCs_Avg_US,
                  color=LDCs,
                  width=bar_width,  # Changed from width to width
                  bottom=Priced_Avg_US)

bars_18 = ax.bar(labels[9],
                  Imports_Avg_US,
                  color=Imports,
                  bottom=Priced_Avg_US + LDCs_Avg_US,
                  width=bar_width)

bars_19 = ax.bar(labels[9],
                  BAT_Avg_US,
                  color=BAT_A,
                  bottom=Priced_Avg_US + LDCs_Avg_US + Imports_Avg_US,
                  width=bar_width)

bars_20 = ax.bar(labels[10],
                  Priced_Elec_Exc_Avg_US,
                  color=CBAM_Covered,
                  edgecolor='white',
                  linestyle='--',
                  width=bar_width)

bars_21 = ax.bar(labels[10],
                  Elec_Avg_US,
                  color=Elec,
                  bottom=Priced_Elec_Exc_Avg_US,
                  width=bar_width)

# flag
bars_flag = ax.bar(labels[11],
                    dataflag,
                    color='white',
                    width=bar_width)

# US Tercile
bars_22 = ax.bar(labels[12],
                  CBAM_Tercile_US,
                  color=CBAM_Covered,
                  edgecolor='white',
                  linestyle='--',
                  width=bar_width,)

bars_23 = ax.bar(labels[13],
                  Priced_Tercile_US,
                  color=CBAM_Covered,
                  width=bar_width,  # Changed from width to width
                  edgecolor='white',
                  linestyle='--')

bars_24 = ax.bar(labels[13],
                  LDCs_Tercile_US,
                  color=LDCs,
                  width=bar_width,  # Changed from width to width
                  bottom=Priced_Tercile_US)

bars_25 = ax.bar(labels[13],
                  Imports_Tercile_US,
                  color=Imports,
                  bottom=Priced_Tercile_US + LDCs_Tercile_US,
                  width=bar_width)

bars_26 = ax.bar(labels[13],
                  BAT_Tercile_US,
                  color=BAT_T,
                  bottom=Priced_Tercile_US + LDCs_Tercile_US + Imports_Tercile_US,
                  width=bar_width)

bars_27 = ax.bar(labels[14],
                  Priced_Elec_Exc_Tercile_US,
                  color=CBAM_Covered,
                  edgecolor='white',
                  linestyle='--',
                  width=bar_width)

bars_28 = ax.bar(labels[14],
                  Elec_Tercile_US,
                  color=Elec,
                  bottom=Priced_Elec_Exc_Tercile_US,
                  width=bar_width)

# flag
bars_flag = ax.bar(labels[15],
                    dataflag,
                    color='white',
                    width=bar_width)
# OECD
# OECD Avg.
bars_29 = ax.bar(labels[16],
                  CBAM_Avg_OECD,
                  color=CBAM_Covered,
                  edgecolor='white',
                  linestyle='--',
                  width=bar_width,)

bars_30 = ax.bar(labels[17],
                  Priced_Avg_OECD,
                  color=CBAM_Covered,
                  width=bar_width,  # Changed from width to width
                  edgecolor='white',
                  linestyle='--')

bars_31 = ax.bar(labels[17],
                  LDCs_Avg_OECD,
                  color=LDCs,
                  width=bar_width,  # Changed from width to width
                  bottom=Priced_Avg_OECD)

bars_32 = ax.bar(labels[17],
                  Imports_Avg_OECD,
                  color=Imports,
                  bottom=Priced_Avg_OECD + LDCs_Avg_OECD,
                  width=bar_width)

bars_33 = ax.bar(labels[17],
                  BAT_Avg_OECD,
                  color=BAT_A,
                  bottom=Priced_Avg_OECD + LDCs_Avg_OECD + Imports_Avg_OECD,
                  width=bar_width)

bars_34 = ax.bar(labels[18],
                  Priced_Elec_Exc_Avg_OECD,
                  color=CBAM_Covered,
                  edgecolor='white',
                  linestyle='--',
                  width=bar_width)

bars_35 = ax.bar(labels[18],
                  Elec_Avg_OECD,
                  color=Elec,
                  bottom=Priced_Elec_Exc_Avg_OECD,
                  width=bar_width)
# flag
bars_flag = ax.bar(labels[19],
                    dataflag,
                    color='white',
                    width=bar_width)
# OECD Tercile
bars_36 = ax.bar(labels[20],
                  CBAM_Tercile_OECD,
                  color=CBAM_Covered,
                  edgecolor='white',
                  linestyle='--',
                  width=bar_width,)

bars_37 = ax.bar(labels[21],
                  Priced_Tercile_OECD,
                  color=CBAM_Covered,
                  width=bar_width,  # Changed from width to width
                  edgecolor='white',
                  linestyle='--')

bars_38 = ax.bar(labels[21],
                  LDCs_Tercile_OECD,
                  color=LDCs,
                  width=bar_width,  # Changed from width to width
                  bottom=Priced_Tercile_OECD)

bars_39 = ax.bar(labels[21],
                  Imports_Tercile_OECD,
                  color=Imports,
                  bottom=Priced_Tercile_OECD + LDCs_Tercile_OECD,
                  width=bar_width)

bars_40 = ax.bar(labels[21],
                  BAT_Tercile_OECD,
                  color=BAT_T,
                  bottom=Priced_Tercile_OECD + LDCs_Tercile_OECD + Imports_Tercile_OECD,
                  width=bar_width)

bars_41 = ax.bar(labels[22],
                  Priced_Elec_Exc_Tercile_OECD,
                  color=CBAM_Covered,
                  edgecolor='white',
                  linestyle='--',
                  width=bar_width)

bars_42 = ax.bar(labels[22],
                  Elec_Tercile_OECD,
                  color=Elec,
                  bottom=Priced_Elec_Exc_Tercile_OECD,
                  width=bar_width)

plt.axvline(x=14 * 0.5, linestyle='--', color='#696969')  
plt.axvline(x=30 * 0.5, linestyle='--', color='#696969')  

ax.set_ylabel('Mt of CO$_2$') 
ax.set_title('Scope 1&2 (Conservative)',fontsize='8')
plt.xticks(rotation=90,fontsize=7) 

# legend_labels = ['CBAM Covered', 'LDCs', 'Imports', 'BAT Average', 'BAT Tercile', 'Electricity']

# legend_handles = [
#     plt.Rectangle((0, 0), 1, 1, color=CBAM_Covered),
#     plt.Rectangle((0, 0), 1, 1, color=LDCs),
#     plt.Rectangle((0, 0), 1, 1, color=Imports),
#     plt.Rectangle((0, 0), 1, 1, color=BAT_A),
#     plt.Rectangle((0, 0), 1, 1, color=BAT_T),
#     plt.Rectangle((0, 0), 1, 1, color=Elec)
# ]

# ax.legend(legend_handles, legend_labels, loc='upper left', bbox_to_anchor=(1, 1),prop={'size': 7})
plt.grid(True, axis='y', linestyle='--', linewidth=0.5, color='#E0E0E0')
plt.tight_layout()
# plt.savefig(r'C:\Users\Jiacheng Zheng\Desktop\Scope 1&2 (Conservative).png', dpi=3600)
# plt.savefig(r'C:\Users\Jiacheng Zheng\Desktop\Figure S1&2 Conservative.svg')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd



# Read Excel file
df = pd.read_excel(r'C:\Users\Jiacheng Zheng\Desktop\放在桌面的文件\draw figures\Python Final\Figure3\Figure 3 stacked bar chart\WTO_OECD.xlsx', sheet_name='Con_S1&2')

# Define data columns
labels = df['Labels']

# EU
CBAM_Avg_EU = df['EU_CBAM_Avg.']
BAT_Avg_EU = df['EU_BAT_Avg.']
Imports_Avg_EU = df['EU_Imports_Avg.']
LDCs_Avg_EU = df['EU_LDCs_Avg.']
Priced_Avg_EU = df['EU_Priced_Avg.']
Elec_Avg_EU = df['EU_Elec_Avg.']
Priced_Elec_Exc_Avg_EU = df['EU_Priced_Elec_Exc_Avg.']

CBAM_Tercile_EU = df['EU_CBAM_Tercile']
BAT_Tercile_EU = df['EU_BAT_Tercile']
Imports_Tercile_EU = df['EU_Imports_Tercile']
LDCs_Tercile_EU = df['EU_LDCs_Tercile']
Priced_Tercile_EU = df['EU_Priced_Tercile']
Elec_Tercile_EU = df['EU_Elec_Tercile']
Priced_Elec_Exc_Tercile_EU = df['EU_Priced_Elec_Exc_Tercile']

# US
CBAM_Avg_US = df['US_CBAM_Avg.']
BAT_Avg_US = df['US_BAT_Avg.']
Imports_Avg_US = df['US_Imports_Avg.']
LDCs_Avg_US = df['US_LDCs_Avg.']
Priced_Avg_US = df['US_Priced_Avg.']
Elec_Avg_US = df['US_Elec_Avg.']
Priced_Elec_Exc_Avg_US = df['US_Priced_Elec_Exc_Avg.']

CBAM_Tercile_US = df['US_CBAM_Tercile']
BAT_Tercile_US = df['US_BAT_Tercile']
Imports_Tercile_US = df['US_Imports_Tercile']
LDCs_Tercile_US = df['US_LDCs_Tercile']
Priced_Tercile_US = df['US_Priced_Tercile']
Elec_Tercile_US = df['US_Elec_Tercile']
Priced_Elec_Exc_Tercile_US = df['US_Priced_Elec_Exc_Tercile']

# OECD
CBAM_Avg_OECD = df['OECD_CBAM_Avg.']
BAT_Avg_OECD = df['OECD_BAT_Avg.']
Imports_Avg_OECD = df['OECD_Imports_Avg.']
LDCs_Avg_OECD = df['OECD_LDCs_Avg.']
Priced_Avg_OECD = df['OECD_Priced_Avg.']
Elec_Avg_OECD = df['OECD_Elec_Avg.']
Priced_Elec_Exc_Avg_OECD = df['OECD_Priced_Elec_Exc_Avg.']

CBAM_Tercile_OECD = df['OECD_CBAM_Tercile']
BAT_Tercile_OECD = df['OECD_BAT_Tercile']
Imports_Tercile_OECD = df['OECD_Imports_Tercile']
LDCs_Tercile_OECD = df['OECD_LDCs_Tercile']
Priced_Tercile_OECD = df['OECD_Priced_Tercile']
Elec_Tercile_OECD = df['OECD_Elec_Tercile']
Priced_Elec_Exc_Tercile_OECD = df['OECD_Priced_Elec_Exc_Tercile']

dataflag = 0

bar_width = 1  # Change from bar_width to bar_width for horizontal bars



CBAM_Covered = '#fa996a'
LDCs = '#FFFF00' # 亮黄色不变
Imports = '#ff7c80'
BAT_A = '#FFDAB9'
BAT_T = '#420d73' 
Elec = '#FF6347'



fig, ax = plt.subplots()  # Adjusted the figsize for a vertical layout

plt.rcParams['font.family'] = 'Garamond'
plt.rcParams['font.style'] = 'normal'



# EU bars
# EU Avg.
bars_1 = ax.bar(labels[0],
                 CBAM_Avg_EU,
                 color=CBAM_Covered,
                 width=bar_width,  # Changed from width to width
                 edgecolor='white',
                 linestyle='--',)
bars_2 = ax.bar(labels[1],
                 Priced_Avg_EU,
                 color=CBAM_Covered,
                 width=bar_width,  # Changed from width to width
                 edgecolor='white',
                 linestyle='--')
bars_3 = ax.bar(labels[1],
                 LDCs_Avg_EU,
                 color=LDCs,
                 width=bar_width,  # Changed from width to width
                 bottom=Priced_Avg_EU)
bars_4 = ax.bar(labels[1],
                 Imports_Avg_EU,
                 color=Imports,
                 bottom=Priced_Avg_EU + LDCs_Avg_EU,
                 width=bar_width)
bars_5 = ax.bar(labels[1],
                 BAT_Avg_EU,
                 color=BAT_A,
                 bottom=Priced_Avg_EU + LDCs_Avg_EU + Imports_Avg_EU,
                 width=bar_width)
bars_6 = ax.bar(labels[2],
                 Priced_Elec_Exc_Avg_EU,
                 color=CBAM_Covered,
                 width=bar_width,  # Changed from width to width
                 edgecolor='white',
                 linestyle='--')
bars_7 = ax.bar(labels[2],
                 Elec_Avg_EU,
                 color=Elec,
                 bottom=Priced_Elec_Exc_Avg_EU,
                 width=bar_width)

# flag
bars_flag = ax.bar(labels[3],
                    dataflag,
                    color='white',
                    width=bar_width)

# EU Tercile
bars_8 = ax.bar(labels[4],
                 CBAM_Tercile_EU,
                 color=CBAM_Covered,
                 edgecolor='white',
                 linestyle='--',
                 width=bar_width,)

bars_9 = ax.bar(labels[5],
                 Priced_Tercile_EU,
                 color=CBAM_Covered,
                 width=bar_width,  # Changed from width to width
                 edgecolor='white',
                 linestyle='--')

bars_10 = ax.bar(labels[5],
                  LDCs_Tercile_EU,
                  color=LDCs,
                  width=bar_width,  # Changed from width to width
                  bottom=Priced_Tercile_EU)

bars_11 = ax.bar(labels[5],
                  Imports_Tercile_EU,
                  color=Imports,
                  bottom=Priced_Tercile_EU + LDCs_Tercile_EU,
                  width=bar_width)

bars_12 = ax.bar(labels[5],
                  BAT_Tercile_EU,
                  color=BAT_T,
                  bottom=Priced_Tercile_EU + LDCs_Tercile_EU + Imports_Tercile_EU,
                  width=bar_width)

bars_13 = ax.bar(labels[6],
                  Priced_Elec_Exc_Tercile_EU,
                  color=CBAM_Covered,
                  edgecolor='white',
                  linestyle='--',
                  width=bar_width)

bars_14 = ax.bar(labels[6],
                  Elec_Tercile_EU,
                  color=Elec,
                  bottom=Priced_Elec_Exc_Tercile_EU,
                  width=bar_width)

# flag
bars_flag = ax.bar(labels[7],
                    dataflag,
                    color='white',
                    width=bar_width)

# US
# US Avg.
bars_15 = ax.bar(labels[8],
                  CBAM_Avg_US,
                  color=CBAM_Covered,
                  edgecolor='white',
                  linestyle='--',
                  width=bar_width,)

bars_16 = ax.bar(labels[9],
                  Priced_Avg_US,
                  color=CBAM_Covered,
                  width=bar_width,  # Changed from width to width
                  edgecolor='white',
                  linestyle='--')

bars_17 = ax.bar(labels[9],
                  LDCs_Avg_US,
                  color=LDCs,
                  width=bar_width,  # Changed from width to width
                  bottom=Priced_Avg_US)

bars_18 = ax.bar(labels[9],
                  Imports_Avg_US,
                  color=Imports,
                  bottom=Priced_Avg_US + LDCs_Avg_US,
                  width=bar_width)

bars_19 = ax.bar(labels[9],
                  BAT_Avg_US,
                  color=BAT_A,
                  bottom=Priced_Avg_US + LDCs_Avg_US + Imports_Avg_US,
                  width=bar_width)

bars_20 = ax.bar(labels[10],
                  Priced_Elec_Exc_Avg_US,
                  color=CBAM_Covered,
                  edgecolor='white',
                  linestyle='--',
                  width=bar_width)

bars_21 = ax.bar(labels[10],
                  Elec_Avg_US,
                  color=Elec,
                  bottom=Priced_Elec_Exc_Avg_US,
                  width=bar_width)

# flag
bars_flag = ax.bar(labels[11],
                    dataflag,
                    color='white',
                    width=bar_width)

# US Tercile
bars_22 = ax.bar(labels[12],
                  CBAM_Tercile_US,
                  color=CBAM_Covered,
                  edgecolor='white',
                  linestyle='--',
                  width=bar_width,)

bars_23 = ax.bar(labels[13],
                  Priced_Tercile_US,
                  color=CBAM_Covered,
                  width=bar_width,  # Changed from width to width
                  edgecolor='white',
                  linestyle='--')

bars_24 = ax.bar(labels[13],
                  LDCs_Tercile_US,
                  color=LDCs,
                  width=bar_width,  # Changed from width to width
                  bottom=Priced_Tercile_US)

bars_25 = ax.bar(labels[13],
                  Imports_Tercile_US,
                  color=Imports,
                  bottom=Priced_Tercile_US + LDCs_Tercile_US,
                  width=bar_width)

bars_26 = ax.bar(labels[13],
                  BAT_Tercile_US,
                  color=BAT_T,
                  bottom=Priced_Tercile_US + LDCs_Tercile_US + Imports_Tercile_US,
                  width=bar_width)

bars_27 = ax.bar(labels[14],
                  Priced_Elec_Exc_Tercile_US,
                  color=CBAM_Covered,
                  edgecolor='white',
                  linestyle='--',
                  width=bar_width)

bars_28 = ax.bar(labels[14],
                  Elec_Tercile_US,
                  color=Elec,
                  bottom=Priced_Elec_Exc_Tercile_US,
                  width=bar_width)

# flag
bars_flag = ax.bar(labels[15],
                    dataflag,
                    color='white',
                    width=bar_width)
# OECD
# OECD Avg.
bars_29 = ax.bar(labels[16],
                  CBAM_Avg_OECD,
                  color=CBAM_Covered,
                  edgecolor='white',
                  linestyle='--',
                  width=bar_width,)

bars_30 = ax.bar(labels[17],
                  Priced_Avg_OECD,
                  color=CBAM_Covered,
                  width=bar_width,  # Changed from width to width
                  edgecolor='white',
                  linestyle='--')

bars_31 = ax.bar(labels[17],
                  LDCs_Avg_OECD,
                  color=LDCs,
                  width=bar_width,  # Changed from width to width
                  bottom=Priced_Avg_OECD)

bars_32 = ax.bar(labels[17],
                  Imports_Avg_OECD,
                  color=Imports,
                  bottom=Priced_Avg_OECD + LDCs_Avg_OECD,
                  width=bar_width)

bars_33 = ax.bar(labels[17],
                  BAT_Avg_OECD,
                  color=BAT_A,
                  bottom=Priced_Avg_OECD + LDCs_Avg_OECD + Imports_Avg_OECD,
                  width=bar_width)

bars_34 = ax.bar(labels[18],
                  Priced_Elec_Exc_Avg_OECD,
                  color=CBAM_Covered,
                  edgecolor='white',
                  linestyle='--',
                  width=bar_width)

bars_35 = ax.bar(labels[18],
                  Elec_Avg_OECD,
                  color=Elec,
                  bottom=Priced_Elec_Exc_Avg_OECD,
                  width=bar_width)
# flag
bars_flag = ax.bar(labels[19],
                    dataflag,
                    color='white',
                    width=bar_width)
# OECD Tercile
bars_36 = ax.bar(labels[20],
                  CBAM_Tercile_OECD,
                  color=CBAM_Covered,
                  edgecolor='white',
                  linestyle='--',
                  width=bar_width,)

bars_37 = ax.bar(labels[21],
                  Priced_Tercile_OECD,
                  color=CBAM_Covered,
                  width=bar_width,  # Changed from width to width
                  edgecolor='white',
                  linestyle='--')

bars_38 = ax.bar(labels[21],
                  LDCs_Tercile_OECD,
                  color=LDCs,
                  width=bar_width,  # Changed from width to width
                  bottom=Priced_Tercile_OECD)

bars_39 = ax.bar(labels[21],
                  Imports_Tercile_OECD,
                  color=Imports,
                  bottom=Priced_Tercile_OECD + LDCs_Tercile_OECD,
                  width=bar_width)

bars_40 = ax.bar(labels[21],
                  BAT_Tercile_OECD,
                  color=BAT_T,
                  bottom=Priced_Tercile_OECD + LDCs_Tercile_OECD + Imports_Tercile_OECD,
                  width=bar_width)

bars_41 = ax.bar(labels[22],
                  Priced_Elec_Exc_Tercile_OECD,
                  color=CBAM_Covered,
                  edgecolor='white',
                  linestyle='--',
                  width=bar_width)

bars_42 = ax.bar(labels[22],
                  Elec_Tercile_OECD,
                  color=Elec,
                  bottom=Priced_Elec_Exc_Tercile_OECD,
                  width=bar_width)

plt.axvline(x=14 * 0.5, linestyle='--', color='#696969')  
plt.axvline(x=30 * 0.5, linestyle='--', color='#696969')  

ax.set_ylabel('Mt of CO$_2$') 
ax.set_title('Scope 1&2 (Conservative)',fontsize='8')
plt.xticks(rotation=90,fontsize=7) 

# legend_labels = ['CBAM Covered', 'LDCs', 'Imports', 'BAT Average', 'BAT Tercile', 'Electricity']

# legend_handles = [
#     plt.Rectangle((0, 0), 1, 1, color=CBAM_Covered),
#     plt.Rectangle((0, 0), 1, 1, color=LDCs),
#     plt.Rectangle((0, 0), 1, 1, color=Imports),
#     plt.Rectangle((0, 0), 1, 1, color=BAT_A),
#     plt.Rectangle((0, 0), 1, 1, color=BAT_T),
#     plt.Rectangle((0, 0), 1, 1, color=Elec)
# ]

# ax.legend(legend_handles, legend_labels, loc='upper left', bbox_to_anchor=(1, 1),prop={'size': 7})
plt.grid(True, axis='y', linestyle='--', linewidth=0.5, color='#E0E0E0')
plt.tight_layout()
# plt.savefig(r'C:\Users\Jiacheng Zheng\Desktop\Scope 1&2 (Conservative).png', dpi=3600)
# plt.savefig(r'C:\Users\Jiacheng Zheng\Desktop\Figure S1&2 Conservative.svg')
plt.show()
